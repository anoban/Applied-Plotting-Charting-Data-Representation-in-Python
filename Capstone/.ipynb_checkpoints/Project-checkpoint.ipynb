# %% [markdown]
# Datasets selected for analyses are from the free material provided by GAPMINDER.ORG, CC-BY LICENSE
# *Source: https://www.gapminder.org/data/*
#
# **`Select an indicator > Society > War & Peace > Refugees > UNHCR Refugees`**
#
# **Selected datasets:
# &emsp;&emsp;    -`Asylum seekers by county of origin`
# &emsp;&emsp;    -`Asylum seekers by county of residence`
# &emsp;&emsp;    -`UNHCR refugees by county of origin`
# &emsp;&emsp;    -`UNHCR refugees by county of residence`**
#
# **Military expenditure as percentage of national GDP data:**
# **`Select an indicator > Society > War & Peace > Military expenditure`**
# *Source: https://data.worldbank.org/indicator/MS.MIL.XPND.GD.ZS*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
import gc

# %%
os.getcwd()
# Out:
# 'D:\\Applied-Plotting-Charting-Data-Representation-in-Python\\Capstone'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'as_from.csv',
#  'as_in.csv',
#  'military_expenditure_percent_of_gdp.csv',
#  'Project.ipynb',
#  'unhcr_refg_by_country_of_residence.csv',
#  'unhcr_refg_from.csv']

# %%
# UNHCR refugees based on country of origin
unhcr_from = pd.read_csv("./unhcr_refg_from.csv")

# UNHCR refugees based on country of residence
unhcr_in = pd.read_csv("./unhcr_refg_by_country_of_residence.csv")

# military expenditure
mil_exp = pd.read_csv("./military_expenditure_percent_of_gdp.csv")

# %%
mil_exp = pd.concat([mil_exp.country, mil_exp.iloc[:, 51:]], axis = 1)
mil_exp
# Out:
#                   country   2010   2011   2012   2013   2014   2015   2016  \
# 0             Afghanistan  1.950  1.820  1.180  1.080  1.300  0.995  0.957
# 1                  Angola  4.180  3.260  3.240  4.460  4.700  3.110  2.730
# 2                 Albania  1.560  1.530  1.490  1.410  1.350  1.160  1.100
# 3    United Arab Emirates  6.040  5.470  5.080  6.030  5.640    NaN    NaN
# 4               Argentina  0.815  0.764  0.785  0.838  0.878  0.850  0.813
# ..                    ...    ...    ...    ...    ...    ...    ...    ...
# 160               Vietnam  2.310  1.980  2.160  2.180  2.290  2.360  2.440
# 161                 Yemen  4.690  4.930  4.570  4.080  3.970    NaN    NaN
# 162          South Africa  1.120  1.100  1.130  1.120  1.110  1.100  1.070
# 163                Zambia  1.380  1.320  1.360  1.360  1.630  1.750  1.430
# 164              Zimbabwe  0.816  1.410  1.860  1.870  1.890  1.890  1.740
#
#       2017   2018   2019   2020
# 0    0.945  1.010  1.120  1.370
# ...

# %%
mil_exp_short = mil_exp.iloc[mil_exp.index[mil_exp.country.isin(unhcr_from.country)], :].reset_index(drop = True)
mil_exp_short = mil_exp_short.drop("2010", axis = 1)
mil_exp_short
# Out:
#                 country  2011   2012   2013   2014   2015   2016   2017  2018  \
# 0  United Arab Emirates  5.47   5.08   6.03   5.64    NaN    NaN    NaN   NaN
# 1               Algeria  4.33   4.46   4.84   5.55   6.27   6.38   5.92  5.47
# 2                Israel  5.79   5.67   5.58   5.75   5.51   5.49   5.53  5.33
# 3                Jordan  5.50   4.69   4.24   4.26   4.26   4.51   4.76  4.64
# 4                Kuwait  3.50   3.41   3.27   3.59   5.01   5.89   5.61  5.10
# 5                 Libya   NaN   3.75   7.64  15.50    NaN    NaN    NaN   NaN
# 6                  Oman  7.35  12.10  11.10  10.10  10.90  12.10   9.64  9.54
# 7          Saudi Arabia  7.23   7.68   8.98  10.70  13.30   9.87  10.20  9.47
# 8           South Sudan  6.09   8.77   6.57   8.62  10.60   4.60   2.35  3.65
# 9                 Yemen  4.93   4.57   4.08   3.97    NaN    NaN    NaN   NaN
#
#    2019   2020
# 0   NaN    NaN
# 1  6.02   6.66
# 2  5.19   5.62
# 3  4.64   4.96
# 4  5.48   6.50
# ...

# %% [markdown]
# ## ***Finding the top 10 countries that spend most on military expenses***

# %%
mean_exp = mil_exp.iloc[:, 1:mil_exp.shape[1]].mean(axis = 1)
mean_mil_exp = pd.Series(data = list(mean_exp) , index = list(mil_exp.country.values))

# %%
list(zip(mil_exp.country.values, mean_exp))[1:10]
# Out:
# [('Angola', 3.0290909090909093),
#  ('Albania', 1.3363636363636362),
#  ('United Arab Emirates', 5.651999999999999),
#  ('Argentina', 0.8010909090909091),
#  ('Armenia', 4.142727272727272),
#  ('Australia', 1.869090909090909),
#  ('Austria', 0.7620909090909092),
#  ('Azerbaijan', 4.268181818181818),
#  ('Burundi', 2.1744444444444446)]

# %%
print("Countries that spends lowest and highest percentages of their national GDP on military are {} and {} \nwith perxentages {} % \
and {} % respectively.".format(mean_mil_exp.index[mean_mil_exp.argmin()], mean_mil_exp.index[mean_mil_exp.argmax()],
             mean_mil_exp.min(), mean_mil_exp.max()))
# Out:
# Countries that spends lowest and highest percentages of their national GDP on military are Costa Rica and Oman
# with perxentages 0.0 % and 9.89181818181818 % respectively.

# %%
top10 = mean_mil_exp.sort_values(ascending = False)[0:10]
top10
# Out:
# Oman                    9.891818
# Saudi Arabia            9.296364
# Libya                   8.963333
# South Sudan             5.895000
# United Arab Emirates    5.652000
# Israel                  5.581818
# Algeria                 5.401818
# Jordan                  4.760000
# Kuwait                  4.647273
# Yemen                   4.448000
# dtype: float64

# %%
plt.figure(figsize = (15, 5))
plt.bar(height = top10.values, x = top10.index)
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# ## ***Refugees in these 20 countries***

# %%
top10.index
# Out:
# Index(['Oman', 'Saudi Arabia', 'Libya', 'South Sudan', 'United Arab Emirates',
#        'Israel', 'Algeria', 'Jordan', 'Kuwait', 'Yemen'],
#       dtype='object')

# %%
ind_refugees_in = np.where(unhcr_in.country.isin(top10.index) == True)[0]
ind_refugees_in
# Out:
# array([  4,  49,  83,  86,  95,  99, 134, 150, 159, 190], dtype=int64)

# %%
unhcr_in = unhcr_in.iloc[ind_refugees_in, :].reset_index(drop = True)
unhcr_in
# Out:
#                 country 1951 1952 1953 1954 1955 1956 1957 1958 1959  ...  \
# 0  United Arab Emirates  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1               Algeria  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2                Israel  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3                Jordan  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4                Kuwait  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 5                 Libya  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 6                  Oman  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 7          Saudi Arabia  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 8           South Sudan  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 9                 Yemen  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#     2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 0    675    628    602    419    663    888    884   1170   1240   1330
# ...

# %%
# let's just consider the years from 2000 to 2020

unhcr_in = pd.concat([unhcr_in.country, unhcr_in.loc[:, unhcr_in.columns[60:]]], axis = 1)
unhcr_in
# Out:
#                 country   2010   2011   2012   2013   2014   2015   2016  \
# 0  United Arab Emirates    538    675    628    602    419    663    888
# 1               Algeria  94.1k  94.1k  94.1k  94.1k  94.1k  94.2k  94.2k
# 2                Israel  25.5k  41.2k  48.5k  48.2k  39.7k  32.9k  30.5k
# 3                Jordan   451k   451k   303k   642k   654k   664k   685k
# 4                Kuwait    185    336    676    633    611    736    935
# 5                 Libya   7920  10.1k   7070  25.6k    28k   9310   9310
# 6                  Oman     78     83    138    138    150    244    316
# 7          Saudi Arabia    578    595    575    557    559    122    136
# 8           South Sudan    NaN   105k   203k   230k   248k   263k   263k
# 9                 Yemen   190k   215k   237k   241k   258k   267k   270k
#
#     2017   2018   2019   2020
# 0    884   1170   1240   1330
# 1  94.2k  94.3k  98.6k  97.7k
# 2  25.7k  18.6k  16.1k   1900
# 3   691k   715k   694k   703k
# ...

# %%
# let's repeat the same for unhchr_from
unhcr_from = unhcr_from.iloc[ind_refugees_in, :].reset_index(drop = True)
unhcr_from = pd.concat([unhcr_from.country, unhcr_from.loc[:, unhcr_from.columns[60:]]], axis = 1)
unhcr_from
# Out:
#                 country  2010  2011  2012  2013  2014   2015   2016   2017  \
# 0  United Arab Emirates   418   484   580    84    84     91    103    137
# 1               Algeria  6670  6100  5660  3640  3510   3470   3710   4020
# 2                Israel  1290  1320  1330  1030   967    787    487    469
# 3                Jordan  2250  2240  2360  1620  1710   1840   1920   2120
# 4                Kuwait   986  1110  1190   971   974   1080   1010   1100
# 5                 Libya  2300  4370  5230  3300  4190   6080   8830  11.2k
# 6                  Oman    62    58    62    20    25     36     35     39
# 7          Saudi Arabia   659   733   811   575   616    686    937   1220
# 8           South Sudan   NaN     0   87k  114k  616k   779k  1.44M  2.44M
# 9                 Yemen  2070  2320  2580  2410  2620  15.9k  18.4k  23.6k
#
#     2018   2019   2020
# 0    169    155    191
# 1   4190   4520   4690
# 2    492    452    398
# 3   2430   2310   2490
# ...

# %%
# damn! there are strings the numeric columns
# some dumbass entered 1000s as ks!
# a function to cast these into floats!

def CastToFloat(column):
    """
    A function that takes a Pandas DataFrame column as input, checks whether that any element in that column
    contains the character "k"and if so, removes that chracter, casts the value to a float and returns it multiplied by 1000!
    If the element does not have a "k" in it, just type casts the string to a float and returns it!
    eg: "123.65k" => 123650.0
    """
    result = list()
    for value in column:
        if "k" in str(value):
            result.append(float(value.replace("k", "")) * 1000)
        elif "M" in str(value):
            result.append(float(value.replace("M", "")) * 1000000)
        else:
            result.append(float(value))
    return pd.Series(data = result, dtype = np.float64)

# %%
col_names = {"country": "country"}
for i in range(11):
    col_names[i] = str(2010 + i)

# %%
col_names
# Out:
# {'country': 'country',
#  0: '2010',
#  1: '2011',
#  2: '2012',
#  3: '2013',
#  4: '2014',
#  5: '2015',
#  6: '2016',
#  7: '2017',
#  8: '2018',
#  9: '2019',
#  10: '2020'}

# %%
unhcr_in = pd.concat([unhcr_in.country, unhcr_in.iloc[:, 1:].apply(CastToFloat, axis = 1)], axis = 1).rename(columns = col_names)

# %%
unhcr_in
# Out:
#                 country      2010      2011      2012      2013      2014  \
# 0  United Arab Emirates     538.0     675.0     628.0     602.0     419.0
# 1               Algeria   94100.0   94100.0   94100.0   94100.0   94100.0
# 2                Israel   25500.0   41200.0   48500.0   48200.0   39700.0
# 3                Jordan  451000.0  451000.0  303000.0  642000.0  654000.0
# 4                Kuwait     185.0     336.0     676.0     633.0     611.0
# 5                 Libya    7920.0   10100.0    7070.0   25600.0   28000.0
# 6                  Oman      78.0      83.0     138.0     138.0     150.0
# 7          Saudi Arabia     578.0     595.0     575.0     557.0     559.0
# 8           South Sudan       NaN  105000.0  203000.0  230000.0  248000.0
# 9                 Yemen  190000.0  215000.0  237000.0  241000.0  258000.0
#
#        2015      2016      2017      2018      2019      2020
# 0     663.0     888.0     884.0    1170.0    1240.0    1330.0
# ...

# %%
unhcr_from = pd.concat([unhcr_from.country, unhcr_from.iloc[:, 1:].apply(CastToFloat, axis = 1)], axis = 1).rename(columns = col_names)
unhcr_from
# Out:
#                 country    2010    2011     2012      2013      2014  \
# 0  United Arab Emirates   418.0   484.0    580.0      84.0      84.0
# 1               Algeria  6670.0  6100.0   5660.0    3640.0    3510.0
# 2                Israel  1290.0  1320.0   1330.0    1030.0     967.0
# 3                Jordan  2250.0  2240.0   2360.0    1620.0    1710.0
# 4                Kuwait   986.0  1110.0   1190.0     971.0     974.0
# 5                 Libya  2300.0  4370.0   5230.0    3300.0    4190.0
# 6                  Oman    62.0    58.0     62.0      20.0      25.0
# 7          Saudi Arabia   659.0   733.0    811.0     575.0     616.0
# 8           South Sudan     NaN     0.0  87000.0  114000.0  616000.0
# 9                 Yemen  2070.0  2320.0   2580.0    2410.0    2620.0
#
#        2015       2016       2017       2018       2019       2020
# 0      91.0      103.0      137.0      169.0      155.0      191.0
# 1    3470.0     3710.0     4020.0     4190.0     4520.0     4690.0
# ...

# %%
unhcr_from = unhcr_from.dropna(axis = 1)
unhcr_from
# Out:
#                 country    2011     2012      2013      2014      2015  \
# 0  United Arab Emirates   484.0    580.0      84.0      84.0      91.0
# 1               Algeria  6100.0   5660.0    3640.0    3510.0    3470.0
# 2                Israel  1320.0   1330.0    1030.0     967.0     787.0
# 3                Jordan  2240.0   2360.0    1620.0    1710.0    1840.0
# 4                Kuwait  1110.0   1190.0     971.0     974.0    1080.0
# 5                 Libya  4370.0   5230.0    3300.0    4190.0    6080.0
# 6                  Oman    58.0     62.0      20.0      25.0      36.0
# 7          Saudi Arabia   733.0    811.0     575.0     616.0     686.0
# 8           South Sudan     0.0  87000.0  114000.0  616000.0  779000.0
# 9                 Yemen  2320.0   2580.0    2410.0    2620.0   15900.0
#
#         2016       2017       2018       2019       2020
# 0      103.0      137.0      169.0      155.0      191.0
# 1     3710.0     4020.0     4190.0     4520.0     4690.0
# ...

# %%
unhcr_in = unhcr_in.dropna(axis = 1)
unhcr_in
# Out:
#                 country      2011      2012      2013      2014      2015  \
# 0  United Arab Emirates     675.0     628.0     602.0     419.0     663.0
# 1               Algeria   94100.0   94100.0   94100.0   94100.0   94200.0
# 2                Israel   41200.0   48500.0   48200.0   39700.0   32900.0
# 3                Jordan  451000.0  303000.0  642000.0  654000.0  664000.0
# 4                Kuwait     336.0     676.0     633.0     611.0     736.0
# 5                 Libya   10100.0    7070.0   25600.0   28000.0    9310.0
# 6                  Oman      83.0     138.0     138.0     150.0     244.0
# 7          Saudi Arabia     595.0     575.0     557.0     559.0     122.0
# 8           South Sudan  105000.0  203000.0  230000.0  248000.0  263000.0
# 9                 Yemen  215000.0  237000.0  241000.0  258000.0  267000.0
#
#        2016      2017      2018      2019      2020
# 0     888.0     884.0    1170.0    1240.0    1330.0
# ...

# %% [markdown]
# # **Now we can just focus on `unhcr_in`, `unhcr_from` & `top10`**
# - `top20` Top 20 countries with highest military expenses in terms of percent of GDP
# - `unhcr_in` Refugees in selected 20 countries
# - `unhcr_from` Refugees from selected 20 countries

# %%
plt.figure(figsize = (20, 10))
plt.rcParams["font.size"] = 12
for year in range(2011, 2021, 1):
    plt.plot(unhcr_from.loc[:, str(year)], linestyle = "dotted", marker = "o", markeredgecolor = "black",
             markersize = 10, label = str(year))
plt.xticks(ticks = np.linspace(0, 9, num = 10), labels = unhcr_from.country)
plt.ylabel("Number of refugees")
plt.xlabel("Countries")
plt.title("Number of refugees from the top 10 countries that spend the most of their \
GDP on military expenses in terms of percentage")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20, 10))
plt.rcParams["font.size"] = 12
for year in range(2010, 2021, 1):
    plt.plot(unhcr_in.loc[:, str(year)], linestyle = "dashed", marker = "o", markeredgecolor = "black",
             markersize = 10, label = str(year))
plt.xticks(ticks = np.linspace(0, 9, num = 10), labels = unhcr_in.country)
plt.ylabel("Number of refugees")
plt.xlabel("Countries")
plt.title("Number of refugees in the top 10 countries that spend the most of their \
GDP on military expenses in terms of percentage")
plt.legend()
plt.show()

# %%
mil_exp_dict = dict()
for country in unhcr_from.country:
    mil_exp_dict[country] = top10[country]
mil_exp_dict
# Out:
# {'United Arab Emirates': 5.651999999999999,
#  'Algeria': 5.4018181818181805,
#  'Israel': 5.581818181818182,
#  'Jordan': 4.76,
#  'Kuwait': 4.647272727272727,
#  'Libya': 8.963333333333333,
#  'Oman': 9.89181818181818,
#  'Saudi Arabia': 9.296363636363637,
#  'South Sudan': 5.895,
#  'Yemen': 4.448}

# %%
plt.figure(figsize = (20, 10))
plt.rcParams["font.size"] = 12
for year in range(2010, 2021, 1):
    plt.plot(unhcr_from.loc[:, str(year)], linestyle = "dotted", marker = "o", markeredgecolor = "black",
             markersize = 10, label = str(year))
for year in range(2010, 2021, 1):
    plt.plot(unhcr_in.loc[:, str(year)], linestyle = "none", marker = "h", markeredgecolor = "black",
             markersize = 12)
plt.plot(mil_exp_dict.keys(), np.array(list(mil_exp_dict.values()), dtype = np.float64) * 100000,
         linestyle = "-", marker = "s", markersize = 5, color = "red")
plt.xticks(ticks = np.linspace(0, 9, num = 10), labels = unhcr_from.country)
plt.ylabel("Number of refugees")
plt.xlabel("Countries")
plt.title("Number of refugees in & from the top 10 countries that spend the most of their \
GDP on military expenses in terms of percentage")
plt.legend()
plt.show()

# %%
plt.rcParams["font.size"] = 10
plt.figure(figsize = (17, 5))
plt.plot(mil_exp_dict.keys(), mil_exp_dict.values(), linestyle = "none", marker = "s", markersize = 10)
plt.ylabel("Military expenditure as percentage of GDP")
plt.xlabel("Countries")
plt.show()

# %%
["axis" + str(i) for i in range(10)];
unhcr_from.country.values
# Out:
# array(['United Arab Emirates', 'Algeria', 'Israel', 'Jordan', 'Kuwait',
#        'Libya', 'Oman', 'Saudi Arabia', 'South Sudan', 'Yemen'],
#       dtype=object)

# %%
mil_exp_dict
# Out:
# {'United Arab Emirates': 5.651999999999999,
#  'Algeria': 5.4018181818181805,
#  'Israel': 5.581818181818182,
#  'Jordan': 4.76,
#  'Kuwait': 4.647272727272727,
#  'Libya': 8.963333333333333,
#  'Oman': 9.89181818181818,
#  'Saudi Arabia': 9.296363636363637,
#  'South Sudan': 5.895,
#  'Yemen': 4.448}

# %%
# let's make a 3 x 3 grid for the first 9 countries
# year on the x axis
# refugees on the y axis

exp_gdp = list(mil_exp_dict.values())[:9]
years = np.arange(2011, 2021, 1)
fig = plt.figure(figsize = (32, 30))
(axis0, axis1, axis2), (axis3, axis4, axis5), (axis6, axis7, axis8) = fig.subplots(nrows = 3,
                                                                           ncols = 3, sharex = True) #, sharey = True)
plt.rcParams["figure.titlesize"] = 30
plt.rcParams["figure.titleweight"] = 900
plt.rcParams["font.size"] = 20
axes = [axis0, axis1, axis2, axis3, axis4, axis5, axis6, axis7, axis8]
fig.suptitle("$Refugees\hspace{1}in\hspace{1}and\hspace{1}from\hspace{1}the\hspace{1}nine\hspace{1}countries\hspace{1}that\hspace{1}spend\hspace{1}most\hspace{1}on\hspace{1}military\hspace{1}expenses\hspace{1}per\hspace{1}total\hspace{1}GDP$",
            y = 0.988)
fig.supylabel("$Number\hspace{1}of\hspace{1}refugees$", x = 0.01)

for i, axis in enumerate(axes):
    axis.plot(years, unhcr_from.iloc[i, 1:].values.astype(int), color = "red", marker = "o", markersize = 10, label = "Refugees from")
    axis.plot(years, unhcr_in.iloc[i, 1:].values.astype(int), color = "green", marker = "o", markersize = 10, label = "Refugees in")
    # axis.plot(years, mil_exp_short.iloc[i, 1:].values.astype(np.float64), color = "blue", marker = "h",
    #         markersize = 10, label ="Mil. expense as % of GDP")
    limits_y = axis.get_ylim()
    axis.text(2019.1, limits_y[1] - ((limits_y[1] - limits_y[0]) / 3.5), s = "{0:.2f}%".format(exp_gdp[i]),
         fontdict = {"fontsize":25, "color":"#2135FF"})
    axis.set_title(unhcr_from.country[i], pad = 20)
axis0.legend()
fig.tight_layout()
plt.savefig("assignment4.jpeg", dpi = 200, pad_inches = 0.35)

# %%
'{0:.3f}'.format(1.4554654)
# Out:
# '1.455'
